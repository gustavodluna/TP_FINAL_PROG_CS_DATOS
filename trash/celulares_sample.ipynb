# %%
import pandas as pd

# %%
ruta="celulares_PySpark.csv"

# %%
df=pd.read_csv(ruta)
df
# Out:
#                               modelo  precio  rating       sim  \
# 0                      OnePlus 11 5G  657.59      89  Dual Sim
# 1          OnePlus Nord CE 2 Lite 5G  239.00      81  Dual Sim
# 2              Samsung Galaxy A14 5G  197.27      75  Dual Sim
# 3               Motorola Moto G62 5G  179.33      81  Dual Sim
# 4                 Realme 10 Pro Plus  298.90      82  Dual Sim
# ..                               ...     ...     ...       ...
# 864       Motorola Moto Edge S30 Pro  418.35      83  Dual Sim
# 865                      Honor X8 5G  179.23      75  Dual Sim
# 866  POCO X4 GT 5G (8GB RAM + 256GB)  346.62      85  Dual Sim
# 867             Motorola Moto G91 5G  239.01      80  Dual Sim
# 868           Samsung Galaxy M52s 5G  298.79      74  Dual Sim
#
#               procesador  bateria        memoria           os    5G    NFC  \
# 0      Snapdragon 8 Gen2     5000  Not Supported  Android v13  True   True
# ...

# %%
df2=df.sample(100)

# %%
df2
# Out:
#                                    modelo   precio  rating       sim  \
# 302                       Infinix Note 12   139.89      74  Dual Sim
# 244  Samsung Galaxy A32 (8GB RAM + 128GB)   197.27      82  Dual Sim
# 593           Samsung Galaxy Note 10 Lite   478.24      83  Dual Sim
# 135                       Xiaomi Redmi 10   114.65      71  Dual Sim
# 171                          LeEco S1 Pro   131.51      65  Dual Sim
# ..                                    ...      ...     ...       ...
# 91                    Apple iPhone 14 Pro  1434.65      75  Dual Sim
# 475                      Huawei Nova 9 SE   239.01      84  Dual Sim
# 303                     Motorola Moto G60   191.29      84  Dual Sim
# 158                Xiaomi Redmi Note 11SE   143.46      80  Dual Sim
# 101                  Xiaomi Redmi K50i 5G   274.99      82  Dual Sim
#
#            procesador  bateria        memoria             os     5G    NFC  \
# ...

# %%
#df2.to_csv("celulares_sample.csv")
