# %% [markdown]
# ![image.png](attachment:f62858b4-71f7-4b3a-a7d0-617b988e84bc.png)

# %%
# LUNA, Gustavo David

# %%
ruta<-"G:\Mi unidad\00-LICENCIATURA DE DATOS\TERCER AÑO\PROG PARA CIENCIA DE DATOS\TPs\TPFINAL\celulares_PySpark.csv"

df<-read.csv(ruta)
df
